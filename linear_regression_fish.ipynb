# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"D:\innotmatics\data.csv\Fish.csv")

# %%
data.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
f_v=data.drop(['Weight'],axis=1)
f_v
# Out:
#     Species  Length1  Length2  Length3   Height   Width
# 0     Bream     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream     26.5     29.0     34.0  12.4440  5.1340
# ..      ...      ...      ...      ...      ...     ...
# 154   Smelt     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 6 columns]

# %%
f_v['Species'].value_counts()
# Out:
# Perch        56
# Bream        35
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# Name: Species, dtype: int64

# %%
c_l=data[['Weight']]
c_l
# Out:
#      Weight
# 0     242.0
# 1     290.0
# 2     340.0
# 3     363.0
# 4     430.0
# ..      ...
# 154    12.2
# 155    13.4
# 156    12.2
# 157    19.7
# 158    19.9
#
# [159 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
lr=LinearRegression()

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()

# %%
f_v['Species']=l.fit_transform(f_v['Species'])

# %%
f_v
# Out:
#      Species  Length1  Length2  Length3   Height   Width
# 0          0     23.2     25.4     30.0  11.5200  4.0200
# 1          0     24.0     26.3     31.2  12.4800  4.3056
# 2          0     23.9     26.5     31.1  12.3778  4.6961
# 3          0     26.3     29.0     33.5  12.7300  4.4555
# 4          0     26.5     29.0     34.0  12.4440  5.1340
# ..       ...      ...      ...      ...      ...     ...
# 154        5     11.5     12.2     13.4   2.0904  1.3936
# 155        5     11.7     12.4     13.5   2.4300  1.2690
# 156        5     12.1     13.0     13.8   2.2770  1.2558
# 157        5     13.2     14.3     15.2   2.8728  2.0672
# 158        5     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 6 columns]

# %%
f_v['Species'].value_counts()
# Out:
# 2    56
# 0    35
# 4    20
# 3    17
# 5    14
# 1    11
# 6     6
# Name: Species, dtype: int64

# %%
f_v.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    int32
#  1   Length1  159 non-null    float64
#  2   Length2  159 non-null    float64
#  3   Length3  159 non-null    float64
#  4   Height   159 non-null    float64
#  5   Width    159 non-null    float64
# dtypes: float64(5), int32(1)
# memory usage: 7.0 KB

# %%
c_l.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Weight  159 non-null    float64
# dtypes: float64(1)
# memory usage: 1.4 KB

# %%
print(f_v.shape)
print(c_l.shape)
# Out:
# (159, 6)
# (159, 1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.scatter(f_v["Species"],c_l)

plt.plot(f_v['Species'].tolist(),model.predict(f_v).reshape(len(model.predict(f_v),)))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.scatter(f_v["Width"],c_l)

plt.plot(f_v['Width'].tolist(),model.predict(f_v).reshape(len(model.predict(f_v),)))

# %%
x_train,x_test,y_train,y_test=train_test_split(f_v,c_l,train_size=0.8,random_state=100,stratify=f_v['Species'])

# %%
y_train
# Out:
#      Weight
# 98    188.0
# 127  1000.0
# 131   300.0
# 45    160.0
# 52    290.0
# ..      ...
# 4     430.0
# 86    120.0
# 128   200.0
# 103   260.0
# 44    145.0
#
# [127 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 127 entries, 98 to 44
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  127 non-null    int32
#  1   Length1  127 non-null    float64
#  2   Length2  127 non-null    float64
#  3   Length3  127 non-null    float64
#  4   Height   127 non-null    float64
#  5   Width    127 non-null    float64
# dtypes: float64(5), int32(1)
# memory usage: 6.4 KB

# %%
x_train_num=x_train.select_dtypes('float64')
x_train_num
# Out:
#      Length1  Length2  Length3   Height   Width
# 98      22.6     24.6     26.2   6.7334  4.1658
# 127     41.1     44.0     46.6  12.4888  7.5958
# 131     34.8     37.3     39.8   6.2884  4.0198
# 45      20.5     22.5     25.3   7.0334  3.8203
# 52      24.0     26.0     29.2   8.8768  4.4968
# ..       ...      ...      ...      ...     ...
# 4       26.5     29.0     34.0  12.4440  5.1340
# 86      20.0     22.0     23.5   6.1100  3.4075
# 128     30.0     32.3     34.8   5.5680  3.3756
# 103     25.4     27.5     28.9   7.1672  4.3350
# 44      20.5     22.0     24.3   6.6339  3.5478
#
# [127 rows x 5 columns]

# %%
x_train_rescaled=pd.DataFrame(scale.fit_transform(x_train_num),columns=x_train_num.columns,index=x_train_num.index)
x_train_rescaled.head()
# Out:
#       Length1   Length2   Length3    Height     Width
# 98  -0.300776 -0.294134 -0.370512 -0.472746 -0.077709
# 127  1.539996  1.504989  1.367218  0.850466  2.024216
# 131  0.913138  0.883642  0.787975 -0.575055 -0.167178
# 45  -0.509728 -0.488884 -0.447176 -0.403773 -0.289433
# 52  -0.161474 -0.164300 -0.114963  0.020039  0.125130

# %%
x_train_la=x_train.select_dtypes('int32')
x_train_la
# Out:
#      Species
# 98         2
# 127        2
# 131        3
# 45         4
# 52         4
# ..       ...
# 4          0
# 86         2
# 128        3
# 103        2
# 44         4
#
# [127 rows x 1 columns]

# %%
y_test
# Out:
#      Weight
# 102   300.0
# 138   567.0
# 151    10.0
# 41    110.0
# 8     450.0
# 134   456.0
# 24    700.0
# 65    150.0
# 119   850.0
# 60   1000.0
# 91    130.0
# 106   250.0
# 118   820.0
# 54    390.0
# 99    180.0
# 7     390.0
# 51    180.0
# 71    300.0
# 126  1000.0
# 23    680.0
# 148     9.7
# 117   650.0
# 111   840.0
# 113   700.0
# 147     7.0
# 16    700.0
# 129   300.0
# 3     363.0
# 15    600.0
# 140   950.0
# 40      0.0
# 121  1015.0

# %%
x_train=pd.concat([x_train_la,x_train_rescaled],axis=1)
x_train
# Out:
#      Species   Length1   Length2   Length3    Height     Width
# 98         2 -0.300776 -0.294134 -0.370512 -0.472746 -0.077709
# 127        2  1.539996  1.504989  1.367218  0.850466  2.024216
# 131        3  0.913138  0.883642  0.787975 -0.575055 -0.167178
# 45         4 -0.509728 -0.488884 -0.447176 -0.403773 -0.289433
# 52         4 -0.161474 -0.164300 -0.114963  0.020039  0.125130
# ..       ...       ...       ...       ...       ...       ...
# 4          0  0.087279  0.113915  0.293914  0.840166  0.515610
# 86         2 -0.559478 -0.535253 -0.600505 -0.616070 -0.542400
# 128        3  0.435533  0.419951  0.362061 -0.740680 -0.561948
# 103        2 -0.022172 -0.025193 -0.140518 -0.373012  0.025978
# 44         4 -0.509728 -0.535253 -0.532359 -0.495622 -0.456423
#
# [127 rows x 6 columns]

# %%
model=lr.fit(x_train,y_train)

# %%
x_test_la=x_test.select_dtypes('int32')
x_test_num=x_test.select_dtypes('float64')
x_test_num
# Out:
#      Length1  Length2  Length3   Height   Width
# 102     25.2     27.3     28.7   8.3230  5.1373
# 138     43.2     46.0     48.7   7.7920  4.8700
# 151     11.3     11.8     13.1   2.2139  1.2838
# 41      19.1     20.8     23.1   6.1677  3.3957
# 8       27.6     30.0     35.1  14.0049  4.8438
# 134     40.0     42.5     45.5   7.2800  4.3225
# 24      31.9     35.0     40.5  16.2405  5.5890
# 65      18.4     20.0     22.4   8.8928  3.2928
# 119     36.9     40.0     42.3  11.9286  7.1064
# 60      37.3     40.0     43.5  12.3540  6.5250
# 91      20.5     22.5     24.0   5.8560  3.6240
# 106     25.9     28.0     29.4   7.8204  4.2042
# 118     36.6     39.0     41.3  12.4313  7.3514
# 54      29.5     31.7     35.0   9.4850  5.3550
# 99      23.0     25.0     26.5   6.4395  3.6835
# 7       27.6     30.0     35.0  12.6700  4.6900
# 51      23.6     25.2     27.9   7.0866  3.9060
# 71      24.0     26.0     29.0  11.3680  4.2340
# 126     40.2     43.5     46.0  12.6040  8.1420
# ...

# %%
x_test_rescaled=pd.DataFrame(scale.transform(x_test_num),columns=x_test_num.columns,index=x_test_num.index)
x_test_rescaled
# Out:
#       Length1   Length2   Length3    Height     Width
# 102 -0.042073 -0.043740 -0.157555 -0.107284  0.517633
# 138  1.748948  1.690465  1.546102 -0.229365  0.353829
# 151 -1.425138 -1.481184 -1.486407 -1.511814 -1.843816
# 41  -0.649030 -0.646539 -0.634579 -0.602805 -0.549631
# 8    0.196730  0.206653  0.387615  1.199029  0.337774
# 134  1.430544  1.365881  1.273517 -0.347078  0.018318
# 24   0.624585  0.670344  0.847603  1.713011  0.794437
# 65  -0.718680 -0.720730 -0.694207  0.023717 -0.612688
# 119  1.122091  1.134036  1.000932  0.721671  1.724309
# 60   1.161891  1.134036  1.103151  0.819474  1.368024
# 91  -0.509728 -0.488884 -0.557914 -0.674467 -0.409727
# 106  0.027578  0.021176 -0.097927 -0.222836 -0.054177
# 118  1.092241  1.041297  0.915749  0.837246  1.874447
# 54   0.385782  0.364308  0.379097  0.159869  0.651040
# 99  -0.260975 -0.257038 -0.344957 -0.540316 -0.373265
# 7    0.196730  0.206653  0.379097  0.892125  0.243524
# ...

# %%
x_test=pd.concat([x_test_la,x_test_rescaled],axis=1)
x_test
# Out:
#      Species   Length1   Length2   Length3    Height     Width
# 102        2 -0.042073 -0.043740 -0.157555 -0.107284  0.517633
# 138        3  1.748948  1.690465  1.546102 -0.229365  0.353829
# 151        5 -1.425138 -1.481184 -1.486407 -1.511814 -1.843816
# 41         4 -0.649030 -0.646539 -0.634579 -0.602805 -0.549631
# 8          0  0.196730  0.206653  0.387615  1.199029  0.337774
# 134        3  1.430544  1.365881  1.273517 -0.347078  0.018318
# 24         0  0.624585  0.670344  0.847603  1.713011  0.794437
# 65         1 -0.718680 -0.720730 -0.694207  0.023717 -0.612688
# 119        2  1.122091  1.134036  1.000932  0.721671  1.724309
# 60         6  1.161891  1.134036  1.103151  0.819474  1.368024
# 91         2 -0.509728 -0.488884 -0.557914 -0.674467 -0.409727
# 106        2  0.027578  0.021176 -0.097927 -0.222836 -0.054177
# 118        2  1.092241  1.041297  0.915749  0.837246  1.874447
# 54         4  0.385782  0.364308  0.379097  0.159869  0.651040
# ...

# %%
predicted=model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(y_test,predicted)
# Out:
# 16201.550461934825

# %%
r2_score(y_test,predicted)
# Out:
# 0.8423696839382729

# %%
mean_absolute_error(y_test,predicted)
# Out:
# 102.56628388712548

# %%
model.coef_
# Out:
# array([[  31.28968592,  367.75212823,  572.05122508, -691.61657447,
#          233.65418382,  -57.27660693]])

# %%
model.intercept_
# Out:
# array([309.49653654])

# %%
import joblib

# %%
joblib.dump(model,r"C:\Users\PC\Data science course\Python\sa_ml_assign\fishf.joblib")
# Out:
# ['C:\\Users\\PC\\Data science course\\Python\\sa_ml_assign\\fishf.joblib']
